# %% [markdown]
# <a href="https://colab.research.google.com/github/diegosalinas04/Extraccion-de-Caracteristicas/blob/main/Extraccion_de_caracteristicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head(2)
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
#
#            228_store_name 229_store_picture               232_type_of_store  \
# 0     Eugene’s Compostura           1 Photo                          Tailor
# 1  Frutas y verduras Angy           1 Photo  Grocery store (aka. nanostore)
#
#    ... 261_technology_organization 262_technology_serve_customers  \
# 0  ...                         NaN                            NaN
# 1  ...                         NaN                            NaN
#
#   263_technology_secure_sales  264_technology_budget  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#    267_technology_investment_customer_preferences  \
# 0                                             NaN
# 1                                             NaN
#
#   234_willingness_participate_workshop  318_shopkeeper_name  \
# 0                                   no                  NaN
# 1                                   no                  NaN
#
#   319_shopkeepers_last_name 236_whatsapp 235_email
# 0                       NaN          NaN       NaN
# 1                       NaN          NaN       NaN
#
# [2 rows x 106 columns]

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer)

# %%
#Filtro por columnas
filtro1=Micro_Retailer.iloc[ : , [1,2,3,8,10,15,23,25,27,30,32,34,35,36,46,55,62,66,74,80]]
filtro1
# Out:
#                 _title       _server_updated_at           _updated_by  \
# 0    November 12, 2022  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1    November 12, 2022  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2    November 12, 2022  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3    November 12, 2022  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4    November 12, 2022  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
# ..                 ...                      ...                   ...
# 166   November 3, 2022  2022-11-03 16:50:48 UTC          Emilio Garza
# 167   November 3, 2022  2022-11-03 16:28:15 UTC          Emilio Garza
# 168   November 3, 2022  2022-11-03 16:28:14 UTC          Emilio Garza
# 169   November 3, 2022  2022-11-03 16:18:37 UTC        Francisco Adán
# 170   November 3, 2022  2022-11-03 16:15:13 UTC          Emilio Garza
#
#     229_store_picture 108_does_the_micro_retailer_has_a_barred_window_  \
# 0             1 Photo                                              yes
# 1             1 Photo                                               no
# 2             1 Photo                                              yes
# 3             1 Photo                                               no
# 4             1 Photo                                              yes
# ..                ...                                              ...
# 166           1 Photo                                              yes
# 167           1 Photo                                               no
# 168           1 Photo                                              yes
# 169           1 Photo                                               no
# 170           1 Photo                                               no
#
#                                      184_store_devices  \
# 0    POS system (i.e. computer + bar code scanner +...
# 1                       Dataphone (i.e. card payments)
# 2    Dataphone (i.e. card payments),POS system (i.e...
# 3    POS system (i.e. computer + bar code scanner +...
# 4                                           Smartphone
# ..                                                 ...
# 166                    Analog cash register,Smartphone
# 167                    Analog cash register,Smartphone
# 168                                         Smartphone
# 169                               Analog cash register
# 170                                         Smartphone
#
#     5_change_store_space_last_year 20_reviews_finances_monthly  \
# 0                        No cambió                         yes
# 1                      Aumentó 15%                         yes
# 2                        No cambió                         yes
# 3                        No cambió                         yes
# 4                        No cambió                         yes
# ..                             ...                         ...
# 166                            NaN                         NaN
# 167                            NaN                         NaN
# 168                            NaN                         NaN
# 169                            NaN                         NaN
# 170                            NaN                         NaN
#
#                          18_sales_records 19_tax_id 310_burnout  \
# 0    Software especializado + computadora       yes          no
# 1                              No lo hago        no          no
# 2    Software especializado + computadora        no          no
# 3    Software especializado + computadora       yes          no
# 4                                En papel       yes          no
# ..                                    ...       ...         ...
# 166                                   NaN       NaN         NaN
# 167                                   NaN       NaN         NaN
# 168                                   NaN       NaN         NaN
# 169                                   NaN       NaN         NaN
# 170                                   NaN       NaN         NaN
#
#     186_internet_connection  \
# 0                       yes
# 1                       yes
# 2                       yes
# 3                       yes
# 4                       yes
# ..                      ...
# 166                     NaN
# 167                     NaN
# 168                     NaN
# 169                     NaN
# 170                     NaN
#
#                                     210_sales_channels  \
# 0    Llamada a Teléfono celular,Llamada a Teléfono ...
# 1                                             WhatsApp
# 2    Redes sociales (e.g. Facebook, Instagram),What...
# 3                              Llamada a Teléfono fijo
# 4                           Llamada a Teléfono celular
# ..                                                 ...
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
#
#                                    189_payment_methods  \
# 0                 Efectivo,Transferencia interbancaria
# 1                 Efectivo,Transferencia interbancaria
# 2               Efectivo,Tarjeta de débito y/o crédito
# 3    Efectivo,Tarjeta de débito y/o crédito,Transfe...
# 4    Efectivo,Tarjeta de débito y/o crédito,Transfe...
# ..                                                 ...
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
#
#     30_payment_methods_large_purchases 60_services 79_delivery_vehicle  \
# 0                                  NaN         NaN                 NaN
# 1                                  NaN         NaN                 NaN
# 2                                  NaN         NaN                 NaN
# 3                                  NaN         NaN                 NaN
# 4                                  NaN         NaN                 NaN
# ..                                 ...         ...                 ...
# 166                                NaN         NaN                 NaN
# 167                                NaN         NaN                 NaN
# 168                                NaN         NaN                 NaN
# 169                                NaN         NaN                 NaN
# 170                                NaN         NaN                 NaN
#
#     311_topups 47_willingness_reorder_suppliers_lower_prices  \
# 0          NaN                                           NaN
# 1          NaN                                           NaN
# 2          NaN                                           NaN
# 3          NaN                                           NaN
# 4          NaN                                           NaN
# ..         ...                                           ...
# 166        NaN                                           NaN
# 167        NaN                                           NaN
# 168        NaN                                           NaN
# 169        NaN                                           NaN
# 170        NaN                                           NaN
#
#     53_special_conditions_suppliers
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 166                             NaN
# 167                             NaN
# 168                             NaN
# 169                             NaN
# 170                             NaN
#
# [171 rows x 20 columns]

# %%
#Corroboramos valores nulos
valores_nulos=filtro1.isnull().sum()
valores_nulos

# %%
filtro1=filtro1.fillna(method="bfill")
# Out:
# <ipython-input-128-2dc9815e0283>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filtro1=filtro1.fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=filtro1.isnull().sum()
valores_nulos
# Out:
# _title                                                0
# _server_updated_at                                    0
# _updated_by                                           0
# 229_store_picture                                     0
# 108_does_the_micro_retailer_has_a_barred_window_      0
# 184_store_devices                                     0
# 5_change_store_space_last_year                        5
# 20_reviews_finances_monthly                           5
# 18_sales_records                                      5
# 19_tax_id                                             5
# 310_burnout                                           5
# 186_internet_connection                               5
# 210_sales_channels                                    5
# 189_payment_methods                                   5
# 30_payment_methods_large_purchases                  112
# 60_services                                           5
# 79_delivery_vehicle                                   5
# 311_topups                                            5
# 47_willingness_reorder_suppliers_lower_prices         5
# 53_special_conditions_suppliers                       5
# dtype: int64

# %%
filtro1.info()

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(filtro1)

# %%
pd.options.display.max_columns = None

# %%
#Análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['_title'])
table1

# %%
#Filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('_title')
Filtro_index

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('_title')
plt.xlabel('')
plt.ylabel('Frecuencia')

# %%
#Análisis univariado de una variable categórica en específico 1
table1= freq_tbl(Micro_Retailer['_server_updated_at'])
table1

# %%
#Filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('_server_updated_at')
Filtro_index1

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(20,16),alpha = 0.5)

# %%
#Análisis univariado de una variable categórica en específico 3
table1= freq_tbl(Micro_Retailer['_updated_by'])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('_updated_by')
Filtro_index1

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['229_store_picture'])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('229_store_picture')
Filtro_index1

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['108_does_the_micro_retailer_has_a_barred_window_'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('108_does_the_micro_retailer_has_a_barred_window_')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['184_store_devices'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('184_store_devices')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(20,16),alpha = 0.5)

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['5_change_store_space_last_year'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('5_change_store_space_last_year')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('5_change_store_space_last_year')
plt.xlabel('')
plt.ylabel('Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['20_reviews_finances_monthly'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('20_reviews_finances_monthly')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['18_sales_records'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('18_sales_records')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['19_tax_id'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('19_tax_id')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(20,16),alpha = 0.5)

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['310_burnout'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('310_burnout')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['186_internet_connection'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('186_internet_connection')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['210_sales_channels'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('210_sales_channels')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['189_payment_methods'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('189_payment_methods')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('189_payment_methods')
plt.xlabel('')
plt.ylabel('Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['30_payment_methods_large_purchases'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('30_payment_methods_large_purchases')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('189_payment_methods')
plt.xlabel('')
plt.ylabel('Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['60_services'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('60_services')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['79_delivery_vehicle'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('79_delivery_vehicle')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['311_topups'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('311_topups')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('189_payment_methods')
plt.xlabel('')
plt.ylabel('Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['47_willingness_reorder_suppliers_lower_prices'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('47_willingness_reorder_suppliers_lower_prices')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['53_special_conditions_suppliers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('53_special_conditions_suppliers')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")
